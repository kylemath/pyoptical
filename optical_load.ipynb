# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Load in example data file and show top rows and some columns

# %%
filename = "data/trigs001a.001"
data = pd.read_csv(filename, skiprows=188, sep='\t')

data.tail()
# Out:
#            time  group  step  mark  flag    A-AC1    A-AC2    A-AC3    A-AC4  \
# 621    879457.5    1.0   1.0   0.0   0.0  3451.67  14.9263  14.0894  15.2783
# 622    879457.5    1.0   1.0   0.0   0.0  3455.33  11.7694  15.4901  10.6489
# 623  879457.562    1.0   1.0   0.0   0.0  3461.80  12.3095  13.6818  12.1413
# 624  879457.562    1.0   1.0   0.0   0.0  3459.69  15.0264  15.8639  13.4216
# 625  #DATA ENDS    NaN   NaN   NaN   NaN      NaN      NaN      NaN      NaN
#
#         A-AC5  ...   D-Ph29   D-Ph30   D-Ph31   D-Ph32   aux-1  digaux  \
# 621  10.84540  ...  356.229  103.302  236.688  182.740  8192.0     0.0
# 622   8.61437  ...   90.449  318.451   40.399  361.657  8192.0     0.0
# 623  11.59240  ...   94.276  381.903  268.674   35.791  8192.0     0.0
# 624  14.55240  ...  153.756  315.945  240.687  133.047  8192.0     0.0
# 625       NaN  ...      NaN      NaN      NaN      NaN     NaN     NaN
#
#      bias-A  bias-B  bias-C  bias-D
# 621     0.0     0.0     0.0     0.0
# ...

# %% [markdown]
# # Practice plotting a few channels

# %%
data[["A-Ph1", "A-Ph2", "A-Ph3", "A-Ph4", "A-Ph5"]].plot()
plt.show()

# %% [markdown]
# # Practice looping through channels and plotting each

# %%
detectors = ['A', 'B', 'C', 'D']
fig, ax = plt.subplots()

for detector in detectors:
    for x in np.arange(32):
        thischan = detector + '-DC' + str(x+1)
        tempchan = (data[thischan] - data[thischan].mean()) / data[thischan].std()
        tempchan.plot(ax=ax)

plt.show()

# %%
[float(data.time[x]) - float(data.time[2]) for x in ]
# Out:
#   File "<ipython-input-62-41adb50f26b2>", line 1
#     [float(data.time[x]) - float(data.time[2]) for x in ]
#                                                         ^
# SyntaxError: invalid syntax

# %%
np.linspace(3,len(data)-2, 1)
# Out:
# array([3.])
